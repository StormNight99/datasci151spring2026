# %% [markdown]
# There are different ways of changing fonts...
# <font size = "4">
# font size 4
#
# other text
# other text
# <font size = "10">
# font size 10
# other text

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %%
print("My name is Victoria Jen")
# Out:
# My name is Victoria Jen
