# %% [markdown]
# This is my first Jupyter notebook
#
#
# <font size = "6">
#
#
# This is my first Jupyter notebook
#
#
# <font size = "12">
#
#
# This is my first Jupyter notebook

# %%
print("My name is Victoria Jen")
# Out:
# My name is Victoria Jen
